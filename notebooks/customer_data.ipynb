# %%
df=spark.read.csv("/Volumes/synchrony/analytics/analytic_data/Customer Data.csv",header=True)

# %%
df.createOrReplaceTempView("customer_data")

# %%
# %sql
select * from customer_data

# %%
# %sql
create or replace table synchrony.analytics.customer_data as select * from customer_data

# %%
# %sql
select * from synchrony.analytics.customer_data

# %%
# %sql
select count(*) from synchrony.analytics.customer_data
