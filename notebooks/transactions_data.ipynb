# %%
df=spark.read.csv("/Volumes/synchrony/analytics/analytic_data/Transactions Data.csv",header=True)

# %%
df.createOrReplaceTempView("transactions_data")

# %%
# %sql
select * from transactions_data

# %%
# %sql
create or replace table synchrony.analytics.transacations_data as select * from transactions_data

# %%
# %sql
select * from synchrony.analytics.transacations_data

# %%
# %sql
select count(*) from synchrony.analytics.transacations_data
