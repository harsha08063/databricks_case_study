# %%
df=spark.read.csv("/Volumes/synchrony/analytics/analytic_data/Payment Code.csv",header=True)

# %%
df.createOrReplaceTempView("payment_code")

# %%
# %sql
select * from payment_code

# %%
# %sql
create or replace table synchrony.analytics.payment_code as select * from payment_code

# %%
# %sql
select * from synchrony.analytics.payment_code
