# %%
df=spark.read.csv("/Volumes/synchrony/analytics/analytic_data/Category Code.csv",header=True)

# %%
df.createOrReplaceTempView("category_code")

# %%
# %sql
select * from category_code

# %%
# %sql
create or replace table synchrony.analytics.category_code as select * from category_code

# %%
# %sql
select * from synchrony.analytics.category_code
